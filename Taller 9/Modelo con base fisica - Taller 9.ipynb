# %%
# !pip install rasterio
# Out:
# Requirement already satisfied: rasterio in c:\users\juan esteban\anaconda3\lib\site-packages (1.3.3)
# Requirement already satisfied: snuggs>=1.4.1 in c:\users\juan esteban\anaconda3\lib\site-packages (from rasterio) (1.4.7)
# Requirement already satisfied: certifi in c:\users\juan esteban\anaconda3\lib\site-packages (from rasterio) (2022.9.14)
# Requirement already satisfied: affine in c:\users\juan esteban\anaconda3\lib\site-packages (from rasterio) (2.3.1)
# Requirement already satisfied: click>=4.0 in c:\users\juan esteban\anaconda3\lib\site-packages (from rasterio) (8.0.4)
# Requirement already satisfied: setuptools in c:\users\juan esteban\anaconda3\lib\site-packages (from rasterio) (63.4.1)
# Requirement already satisfied: numpy>=1.18 in c:\users\juan esteban\anaconda3\lib\site-packages (from rasterio) (1.21.5)
# Requirement already satisfied: cligj>=0.5 in c:\users\juan esteban\anaconda3\lib\site-packages (from rasterio) (0.7.2)
# Requirement already satisfied: attrs in c:\users\juan esteban\anaconda3\lib\site-packages (from rasterio) (21.4.0)
# Requirement already satisfied: click-plugins in c:\users\juan esteban\anaconda3\lib\site-packages (from rasterio) (1.1.1)
# Requirement already satisfied: colorama in c:\users\juan esteban\appdata\roaming\python\python39\site-packages (from click>=4.0->rasterio) (0.4.6)
# Requirement already satisfied: pyparsing>=2.1.6 in c:\users\juan esteban\appdata\roaming\python\python39\site-packages (from snuggs>=1.4.1->rasterio) (3.0.9)

# %%
import rasterio as rio
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Variables

# %% [markdown]
# ### Cohesion:

# %%
raster = rio.open('https://github.com/jegomezc/Cartografia-Geotecnica/blob/main/Base%20fisica/Cohesion1.tif?raw=true') # (kN/m2)
cohesion=raster.read(1)
cohesion=np.where(cohesion==cohesion[0,0],np.nan,cohesion)
plt.imshow(cohesion)
plt.colorbar();
np.shape(cohesion)
# Out:
# (151, 204)

# %% [markdown]
# ### Friccion:

# %%
raster = rio.open('https://github.com/jegomezc/Cartografia-Geotecnica/blob/main/Base%20fisica/friccion1.tif?raw=true') #(radianes)
friccion=raster.read(1)
friccion=np.where(friccion==friccion[0,0],np.nan,friccion) #ya py lee los nans
plt.imshow(friccion)
plt.colorbar();
np.shape(friccion)
# Out:
# (151, 204)

# %% [markdown]
# ### Peso especifico:

# %%
raster = rio.open('https://github.com/jegomezc/Cartografia-Geotecnica/blob/main/Base%20fisica/peso_especif1.tif?raw=true') #(kN/m3)
peso=raster.read(1)
peso=np.where(peso==peso[0,0],np.nan,peso)
plt.imshow(peso)
plt.colorbar();
np.shape(peso)
# Out:
# (151, 204)

# %% [markdown]
# ### Permeabilidad:

# %%
raster = rio.open('https://github.com/jegomezc/Cartografia-Geotecnica/blob/main/Base%20fisica/Permeabilidad1.tif?raw=true') #(cm/hora)
ks=raster.read(1)
ks[0,0]
ks=np.where(ks==ks[0,0],np.nan,ks)
plt.imshow(ks)
plt.colorbar();
np.shape(ks)
# Out:
# (151, 204)

# %% [markdown]
# ### Espesor:

# %%
raster = rio.open('https://github.com/jegomezc/Cartografia-Geotecnica/blob/main/Base%20fisica/espesor1.tif?raw=true') #(m)
espesor=raster.read(1)
espesor[0,0]
espesor=np.where(espesor==ks[0,0],np.nan,espesor)
plt.imshow(espesor)
plt.colorbar();
np.shape(espesor)
# Out:
# (151, 204)

# %% [markdown]
# ### Pendiente:

# %%
raster = rio.open('https://github.com/jegomezc/Cartografia-Geotecnica/blob/main/VARIABLES/PEND1.tif?raw=true')
pendiente=raster.read(1)
pendiente=np.where(pendiente<0,np.nan,pendiente)
plt.imshow(pendiente);
plt.colorbar();
pendiente_vector=pendiente.ravel()
pendiente_vector_MenM=pendiente_vector[~np.isnan(pendiente_vector)]
np.shape(pendiente)
# Out:
# (151, 204)

# %% [markdown]
# ### Acumulacion de flujo:

# %%
raster = rio.open('https://github.com/jegomezc/Cartografia-Geotecnica/blob/main/Base%20fisica/FlowAcc_final1.tif?raw=true') #(m2)
flujo=raster.read(1)
flujo=np.where(flujo==flujo[0,0],np.nan,flujo)
plt.imshow(flujo)
plt.colorbar();
np.shape(flujo)
# Out:
# (151, 204)

# %%
cohesion=np.where ( geologia==1,13,geologia )
cohesion=np.where ( cohesion==2,33,cohesion )
cohesion=np.where ( cohesion==3,25,cohesion )
cohesion=np.where ( cohesion==4,24,cohesion )
cohesion=np.where ( cohesion==5,15,cohesion )
cohesion=np.where ( cohesion==6,13,cohesion )

plt.imshow(cohesion)
plt.colorbar()
print(np.unique(cohesion));
# Out:
# [ 0. 13. 15. 24. 25. 33. nan]

# %%
peso=np.where ( geologia==1,16.5,geologia )
peso=np.where ( peso==2,15.8,peso )
peso=np.where ( peso==3,18.1,peso )
peso=np.where ( peso==4,16.7,peso )
peso=np.where ( peso==5,16.8,peso )
peso=np.where ( peso==6,16.5,peso )

plt.imshow(peso)
plt.colorbar()
print(np.unique(peso));
# Out:
# [ 0.  15.8 16.5 16.7 16.8 18.1  nan]

# %%
friccion=np.where ( geologia==1,0.488692,geologia )
friccion=np.where ( friccion==2,0.663225,friccion )
friccion=np.where ( friccion==3,0.401426,friccion )
friccion=np.where ( friccion==4,0.575959,friccion )
friccion=np.where ( friccion==5,0.541052,friccion )
friccion=np.where ( friccion==6,0.488692,friccion )

plt.imshow(friccion)
plt.colorbar()
print(np.unique(friccion));
# Out:
# [0.       0.401426 0.488692 0.541052 0.575959 0.663225      nan]

# %%
ks=np.where ( geologia==1,0.018,geologia )
ks=np.where ( ks==2,0.030,ks )
ks=np.where ( ks==3,0.198,ks )
ks=np.where ( ks==4,0.036,ks )
ks=np.where ( ks==5,0.15,ks )
ks=np.where ( ks==6,0.018,ks )

plt.imshow(ks)
plt.colorbar()
print(np.unique(ks));
# Out:
# [0.    0.018 0.03  0.036 0.15  0.198   nan]

# %%
espesor = np.where(pendiente<15, 15, np.where ( (np.logical_and (pendiente>=15, pendiente<40 )),(pendiente*-0.43)+21.43,pendiente))
espesor = np.where ( (np.logical_and (espesor>=40, espesor<60 )),5,espesor )
espesor = np.where (espesor>60, 2, espesor)

plt.imshow(espesor)
plt.colorbar()
print(np.unique(espesor));
# Out:
# [ 2.         4.2311115  4.235079  ... 14.977488  15.               nan]

# %%
cohesion=np.where(cohesion==cohesion[0,0],np.nan,cohesion)
friccion=np.where(friccion==friccion[0,0],np.nan,friccion)
ks=np.where(ks==ks[0,0],np.nan,ks)
peso=np.where(peso==peso[0,0],np.nan,peso)
flow_acc=flow_acc*25
flow_acc=np.where(flow_acc==flow_acc[0,0],np.nan,flow_acc)
pendiente= pendiente*3.1415926/180
pendiente=np.where(pendiente==pendiente[0,0],np.nan,pendiente)
espesor=np.where(espesor==espesor[0,0],np.nan,espesor)

# %%
GammaW   = 9.81 #peso unitario del agua [kN/m3]
dx = 12.5 # resolucion espacial del raster [m]
q = 100 #intensidad de la precipitacion [mm/h]

# %%
"STABILITY ANALYSIS"

MatEst = np.zeros(pendiente.shape)
Matq   = np.zeros(pendiente.shape)

M4=flujo/dx
M5=((0.01 * ks * (espesor * np.cos(pendiente)) * np.sin(pendiente)) / (0.001*q)) * ((peso / GammaW) * (1 - np.tan(pendiente) / np.tan(friccion)) + (cohesion / (GammaW * espesor * np.cos(pendiente)**2 * np.tan(friccion)))) 
MatEst1=np.where(M4>M5,3,MatEst) #  unstable

MatEst2=np.where(M4<=M5,4,MatEst1) # Stable

M1=np.tan(pendiente)
M2=(1 - (GammaW/peso)) * np.tan(friccion) + (cohesion / (peso * espesor * np.cos(pendiente)**2))
MatEst3  =np.where(M1<M2,1,MatEst2) # Unconditionally stable
	
M3=np.tan(friccion) + (cohesion / (peso * espesor * np.cos(pendiente)**2))
MatEst4  =  np.where(M1>=M3,2,MatEst3) # Unconditionally Unstable

Matq = (1000 * 0.01 * ks * espesor * np.cos(pendiente) * np.sin(pendiente)) * (dx / flujo) * ((peso / GammaW) * (1 - (np.tan(pendiente) / np.tan(friccion))) + cohesion / (GammaW * espesor * np.cos(pendiente)**2 * np.tan(friccion)))
np.nanmin(Matq)

MatEst=np.where(MatEst4 == 0, np.nan,MatEst4)
Matq=np.where(Matq==np.inf,np.nanmax(Matq[Matq!=np.inf]),Matq)

Matq = np.where(M1<M2,-1,np.where(M1>=M3,-2,Matq))
# Out:
# C:\Users\Juan Esteban\AppData\Local\Temp\ipykernel_17216\3860987734.py:7: RuntimeWarning: divide by zero encountered in true_divide
#   M5=((0.01 * ks * (espesor * np.cos(pendiente)) * np.sin(pendiente)) / (0.001*q)) * ((peso / GammaW) * (1 - np.tan(pendiente) / np.tan(friccion)) + (cohesion / (GammaW * espesor * np.cos(pendiente)**2 * np.tan(friccion))))
# C:\Users\Juan Esteban\AppData\Local\Temp\ipykernel_17216\3860987734.py:7: RuntimeWarning: invalid value encountered in true_divide
#   M5=((0.01 * ks * (espesor * np.cos(pendiente)) * np.sin(pendiente)) / (0.001*q)) * ((peso / GammaW) * (1 - np.tan(pendiente) / np.tan(friccion)) + (cohesion / (GammaW * espesor * np.cos(pendiente)**2 * np.tan(friccion))))
# C:\Users\Juan Esteban\AppData\Local\Temp\ipykernel_17216\3860987734.py:7: RuntimeWarning: invalid value encountered in multiply
#   M5=((0.01 * ks * (espesor * np.cos(pendiente)) * np.sin(pendiente)) / (0.001*q)) * ((peso / GammaW) * (1 - np.tan(pendiente) / np.tan(friccion)) + (cohesion / (GammaW * espesor * np.cos(pendiente)**2 * np.tan(friccion))))
# C:\Users\Juan Esteban\AppData\Local\Temp\ipykernel_17216\3860987734.py:13: RuntimeWarning: divide by zero encountered in true_divide
#   M2=(1 - (GammaW/peso)) * np.tan(friccion) + (cohesion / (peso * espesor * np.cos(pendiente)**2))
# C:\Users\Juan Esteban\AppData\Local\Temp\ipykernel_17216\3860987734.py:13: RuntimeWarning: invalid value encountered in multiply
#   M2=(1 - (GammaW/peso)) * np.tan(friccion) + (cohesion / (peso * espesor * np.cos(pendiente)**2))
# C:\Users\Juan Esteban\AppData\Local\Temp\ipykernel_17216\3860987734.py:13: RuntimeWarning: invalid value encountered in true_divide
#   M2=(1 - (GammaW/peso)) * np.tan(friccion) + (cohesion / (peso * espesor * np.cos(pendiente)**2))
# C:\Users\Juan Esteban\AppData\Local\Temp\ipykernel_17216\3860987734.py:16: RuntimeWarning: invalid value encountered in true_divide
#   M3=np.tan(friccion) + (cohesion / (peso * espesor * np.cos(pendiente)**2))
# C:\Users\Juan Esteban\AppData\Local\Temp\ipykernel_17216\3860987734.py:19: RuntimeWarning: divide by zero encountered in true_divide
#   Matq = (1000 * 0.01 * ks * espesor * np.cos(pendiente) * np.sin(pendiente)) * (dx / flujo) * ((peso / GammaW) * (1 - (np.tan(pendiente) / np.tan(friccion))) + cohesion / (GammaW * espesor * np.cos(pendiente)**2 * np.tan(friccion)))
# C:\Users\Juan Esteban\AppData\Local\Temp\ipykernel_17216\3860987734.py:19: RuntimeWarning: invalid value encountered in multiply
#   Matq = (1000 * 0.01 * ks * espesor * np.cos(pendiente) * np.sin(pendiente)) * (dx / flujo) * ((peso / GammaW) * (1 - (np.tan(pendiente) / np.tan(friccion))) + cohesion / (GammaW * espesor * np.cos(pendiente)**2 * np.tan(friccion)))
# C:\Users\Juan Esteban\AppData\Local\Temp\ipykernel_17216\3860987734.py:19: RuntimeWarning: invalid value encountered in true_divide
#   Matq = (1000 * 0.01 * ks * espesor * np.cos(pendiente) * np.sin(pendiente)) * (dx / flujo) * ((peso / GammaW) * (1 - (np.tan(pendiente) / np.tan(friccion))) + cohesion / (GammaW * espesor * np.cos(pendiente)**2 * np.tan(friccion)))

# %%
plt.imshow(MatEst)
plt.colorbar()

# %%
plt.imshow(Matq)
plt.colorbar()

# %%
Vol = np.where(np.logical_or(MatEst==2, MatEst==3), espesor*12.5*12.5, 0)

with rio.open('Vol.tif', 'w', 
              driver='Gtiff',height=raster.shape[0],width=raster.shape[1],count=1,
              dtype='float64',nodata=-999,crs=raster.crs,transform=raster.transform) as dst:
    dst.write(Vol,1) 

plt.imshow(Vol)
plt.colorbar()
